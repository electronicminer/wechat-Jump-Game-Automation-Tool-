# %%
import pyautogui
import cv2
import numpy as np
import time
import keyboard
while (1):
    if keyboard.is_pressed('1'):
        x1, y1 = pyautogui.position()  # 返回鼠标的坐标
        print(x1, y1)
    if keyboard.is_pressed('2'):
        x2, y2 = pyautogui.position()  # 返回鼠标的坐标
        print(x2, y2)
    if keyboard.is_pressed('q'):
        break
# Out:
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 24 420
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436
# 708 1436

# %%
def detect_player():
    screenshot = pyautogui.screenshot(region=(x1, y1, x2-x1, y2-y1))
    screenshot = np.array(screenshot)
    screenshot = cv2.cvtColor(screenshot, cv2.COLOR_RGB2BGR)

    # 保存截图用于调试
    cv2.imwrite('template.png', screenshot)
    target = cv2.imread('target.png', 0)
    template = cv2.imread('template.png', 0)
    result = cv2.matchTemplate(template, target, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
    top_left = max_loc

    # 获取目标图像的宽度和高度
    h, w = target.shape

    # 计算目标图像的右下角坐标
    bottom_right = (top_left[0] + w, top_left[1] + h)

    # 在截图中画出矩形框标记目标图像的位置
    cv2.rectangle(screenshot, top_left, bottom_right, (0, 255, 0), 2)
    # print(top_left, bottom_right)
    cv2.circle(screenshot, (top_left[0]+w//2, top_left[1]+h-20), 10, (0, 0, 255), -1)
    # 显示带有矩形框的截图
    # cv2.imshow('Screenshot', screenshot)
    # cv2.waitKey (0)  

    return top_left[0]+w//2, top_left[1]+h-20, top_left[0], top_left[1]

def detect_brick(player_x, player_y):
    screenshot = pyautogui.screenshot(region=(x1, y1, x2-x1, y2-y1-600))
    screenshot = np.array(screenshot)
    screenshot = cv2.cvtColor(screenshot, cv2.COLOR_RGB2BGR)

    # 保存截图用于调试
    cv2.imwrite('template.png', screenshot)
    img=cv2.imread('template.png')
    img=cv2.GaussianBlur(img,(5,5),0)
    canny = cv2.Canny(img, 1, 10)
    h, w = canny.shape
    for y_ in range(player_y,y2-y1-600):
        for x_ in range(player_x,player_x+45):
            canny[y_][x_] = 0
    print(h, w)
    center_x, center_y = 0, 0
    max_x = 0
    for y in range(h):
        for x in range(w):
            if canny[y, x] == 255:
                if center_x == 0:
                    center_x = x
                if x > max_x:
                    center_y = y
                    max_x = x
    cv2.imwrite('canny.png', canny)
    
    cv2.circle(screenshot, (center_x, center_y), 10, (0, 0, 255), -1)
    
    cv2.imshow('Screenshot', screenshot)
    cv2.waitKey (0) 
    cv2.imshow('canny', canny)
    cv2.waitKey (0) 
    return center_x, center_y
x5,y5,x6,y6=detect_player()
detect_brick(x6,y6)

# 639 871
# Out:
# 416 684
# (6, 0)

# %%
while True:  # 获取鼠标当前位置
    time.sleep(1.5)
    x3, y3 = pyautogui.position()
    x5,y5,x6,y6=detect_player()
    x4, y4 = detect_brick(x5,y5)
    print(f"brick position: ({x4}, {y4})")
    
    dis=((x5-x4)**2+(y5-y4)**2)**0.5
    dalay_time_s=dis/530
    print(f'distance={dis}\nclick_time={dalay_time_s}\n')
    pyautogui.mouseDown(x3, y3, button='left')
    time.sleep(dalay_time_s)
    pyautogui.mouseUp(x3, y3, button='left')
    if keyboard.is_pressed('q'):
        break

#
# Out:
# 416 684
# brick position: (6, 0)
# distance=537.1042729303128
# click_time=1.01340428854776
#
# 416 684
# brick position: (6, 323)
# distance=421.04750325824284
# click_time=0.7944292514306469
#
# 416 684
# brick position: (6, 323)
# distance=611.1211009284493
# click_time=1.1530586809970742
#
# 416 684
# brick position: (6, 323)
# distance=611.1211009284493
# click_time=1.1530586809970742
#
# 416 684
# brick position: (6, 0)
# distance=708.3078426785912
# click_time=1.3364298918463986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 while True:  # 获取鼠标当前位置
# ----> 2     time.sleep(1.5)
#       3     x3, y3 = pyautogui.position()
#       4     x5,y5,x6,y6=detect_player()
#
# KeyboardInterrupt:

# %%
# while True:  # 获取鼠标当前位置
    
#     while(1):
#         if keyboard.is_pressed('q'):
#             break
#     x3, y3 = pyautogui.position()
#     x5,y5,x6,y6=detect_player()
#     # x4, y4 = detect_brick(x5,y5)
#     print(f"brick position: ({x4}, {y4})")
    
#     dis=((x5-x3)**2+(y5-y3)**2)**0.5
#     dalay_time_s=dis/530
#     print(f'distance={dis}\nclick_time={dalay_time_s}\n')
#     pyautogui.mouseDown(x3, y3, button='left')
#     time.sleep(dalay_time_s)
#     pyautogui.mouseUp(x3, y3, button='left')
# Out:
# brick position: (2, 7)
# distance=324.6074552440224
# click_time=0.6124668966868347
#
# brick position: (2, 7)
# distance=194.85892332659543
# click_time=0.3676583458992367
#
# brick position: (2, 7)
# distance=177.67385851610248
# click_time=0.3352336953134009
#
# brick position: (2, 7)
# distance=278.23730878514476
# click_time=0.5249760543115939
#
# brick position: (2, 7)
# distance=253.71243564319033
# click_time=0.47870270876073645
#
# brick position: (2, 7)
# distance=304.59973736035954
# click_time=0.5747164855855841
#
# brick position: (2, 7)
# distance=403.6545552821125
# click_time=0.761612368456816
#
# brick position: (2, 7)
# distance=171.32717239247253
# click_time=0.32325881583485383
#
# brick position: (2, 7)
# distance=319.3900436770063
# click_time=0.6026227239188798
#
# brick position: (2, 7)
# distance=351.89913327543167
# click_time=0.6639606288215691
#
# brick position: (2, 7)
# distance=354.24426600863984
# click_time=0.6683854075634714
#
# brick position: (2, 7)
# distance=344.81879299133334
# click_time=0.6506014962100629
#
# brick position: (2, 7)
# distance=168.1903683330291
# click_time=0.3173403176094889
#
# brick position: (2, 7)
# distance=363.5945544146667
# click_time=0.6860274611597484
#
# brick position: (2, 7)
# distance=290.37389689846435
# click_time=0.5478752771669139
#
# brick position: (2, 7)
# distance=190.76687343456672
# click_time=0.3599374970463523
#
# brick position: (2, 7)
# distance=239.76655313033135
# click_time=0.45238972288741763
#
# brick position: (2, 7)
# distance=369.67553340733815
# click_time=0.6975010064289399
#
# brick position: (2, 7)
# distance=244.22940035957996
# click_time=0.460810189357698
#
# brick position: (2, 7)
# distance=338.4981536138713
# click_time=0.6386757615356062
#
# brick position: (2, 7)
# distance=314.92538798896476
# click_time=0.5941988452621977
#
# brick position: (2, 7)
# distance=412.1710809845834
# click_time=0.7776812848765724
#
# brick position: (2, 7)
# distance=222.72853431924702
# click_time=0.42024251758348496
#
# brick position: (2, 7)
# distance=246.3331078032346
# click_time=0.4647794486853483
#
# brick position: (2, 7)
# distance=163.37074401495514
# click_time=0.3082466868206701
#
# brick position: (2, 7)
# distance=158.59697348940804
# click_time=0.2992395726215246
#
# brick position: (2, 7)
# distance=130.6981254647518
# click_time=0.24660023672594678
#
# brick position: (2, 7)
# distance=392.1084033784535
# click_time=0.7398271761857613
#
# brick position: (2, 7)
# distance=242.24367896810023
# click_time=0.4570635452228306
#
# brick position: (2, 7)
# distance=162.88953311984167
# click_time=0.3073387417355503
#
# brick position: (2, 7)
# distance=397.3675880088863
# click_time=0.7497501660545024
#
# brick position: (2, 7)
# distance=293.1381926668717
# click_time=0.5530909295601353
#
# brick position: (2, 7)
# distance=341.9897659287482
# click_time=0.6452637092995249
#
# brick position: (2, 7)
# distance=204.65825172711703
# click_time=0.38614764476814534
#
# brick position: (2, 7)
# distance=355.0056337581138
# click_time=0.6698219504870071
#
# brick position: (2, 7)
# distance=166.58031096140985
# click_time=0.31430247351209406
#
# brick position: (2, 7)
# distance=145.82523787054146
# click_time=0.27514195824630466
#
# brick position: (2, 7)
# distance=190.03157632351525
# click_time=0.35855014400663254
#
# brick position: (2, 7)
# distance=292.6585040623286
# click_time=0.5521858567213747
#
# brick position: (2, 7)
# distance=322.37400639629743
# click_time=0.6082528422571649
#
# brick position: (2, 7)
# distance=247.9697562203907
# click_time=0.4678674645667749
#
# brick position: (2, 7)
# distance=242.39636960977776
# click_time=0.4573516407731656
#
# brick position: (2, 7)
# distance=240.01041644062033
# click_time=0.45284984234079306
#
# brick position: (2, 7)
# distance=212.47352776287215
# click_time=0.40089344860919274
#
# brick position: (2, 7)
# distance=322.37400639629743
# click_time=0.6082528422571649
#
# brick position: (2, 7)
# distance=261.36947029062134
# click_time=0.49314994394456857
#
# brick position: (2, 7)
# distance=210.98341167020692
# click_time=0.3980819088117112
#
# brick position: (2, 7)
# distance=365.60361048545457
# click_time=0.6898181329914237
#
# brick position: (2, 7)
# distance=133.6899397860587
# click_time=0.2522451694076579
#
# brick position: (2, 7)
# distance=247.88707106261108
# click_time=0.4677114548351153
#
# brick position: (2, 7)
# distance=155.7080601638849
# click_time=0.293788792762047
#
# brick position: (2, 7)
# distance=251.81342299408902
# click_time=0.47511966602658307
#
# brick position: (2, 7)
# distance=209.74746720759228
# click_time=0.3957499381275326
#
# brick position: (2, 7)
# distance=287.020905161976
# click_time=0.5415488776641056
#
# brick position: (2, 7)
# distance=395.42508772206145
# click_time=0.7460850711737008
#
# brick position: (2, 7)
# distance=130.6981254647518
# click_time=0.24660023672594678
#
# brick position: (2, 7)
# distance=325.38285142275095
# click_time=0.6139299083448131
#
# brick position: (2, 7)
# distance=315.79265349276255
# click_time=0.5958351952693633
#
# brick position: (2, 7)
# distance=345.3129015834769
# click_time=0.6515337765725979
#
# brick position: (2, 7)
# distance=313.82319863260585
# click_time=0.59211924270303
#
# brick position: (2, 7)
# distance=152.11837495845134
# click_time=0.28701580180839875
#
# brick position: (2, 7)
# distance=333.7663853655727
# click_time=0.6297478969161749
#
# brick position: (2, 7)
# distance=323.47179166041667
# click_time=0.6103241352083333
#
# brick position: (2, 7)
# distance=201.54652068443156
# click_time=0.38027645412156896
#
# brick position: (2, 7)
# distance=183.17205026968497
# click_time=0.34560764201827354
#
# brick position: (2, 7)
# distance=412.0436870041816
# click_time=0.7774409188758143
#
# brick position: (2, 7)
# distance=264.31988196123274
# click_time=0.49871675841742025
#
# brick position: (2, 7)
# distance=347.81604333325396
# click_time=0.6562566855344414
#
# brick position: (2, 7)
# distance=321.2553501500014
# click_time=0.6061421700943422
#
# brick position: (2, 7)
# distance=392.23079940259663
# click_time=0.740058112080371
#
# brick position: (2, 7)
# distance=204.79257799051214
# click_time=0.3864010905481361
#
# brick position: (2, 7)
# distance=234.4120304079976
# click_time=0.4422868498264106
#
# brick position: (2, 7)
# distance=134.73678042761748
# click_time=0.25422034042946695
#
# brick position: (2, 7)
# distance=145.49914089093448
# click_time=0.27452668092629146
#
# brick position: (2, 7)
# distance=92.13576938409967
# click_time=0.17384107430962203
#
# brick position: (2, 7)
# distance=415.1457575358322
# click_time=0.7832938821430796
#
# brick position: (2, 7)
# distance=236.30488780387088
# click_time=0.4458582788752281
#
# brick position: (2, 7)
# distance=151.2679741386127
# click_time=0.28541127195964655
#
# brick position: (2, 7)
# distance=394.1826987578222
# click_time=0.7437409410524948
#
# brick position: (2, 7)
# distance=265.4806960967219
# click_time=0.5009069737673998
#
# brick position: (2, 7)
# distance=328.45243186799513
# click_time=0.619721569562255
#
# brick position: (2, 7)
# distance=182.1318203939114
# click_time=0.34364494413945545
#
# brick position: (2, 7)
# distance=345.3056616969956
# click_time=0.6515201164094258
#
# brick position: (2, 7)
# distance=156.66843970627906
# click_time=0.2956008296344888
#
# brick position: (2, 7)
# distance=123.4908903522847
# click_time=0.23300167990997112
#
# brick position: (2, 7)
# distance=199.32385707686876
# click_time=0.3760827492016392
#
# brick position: (2, 7)
# distance=319.4761336938958
# click_time=0.6027851579130109
#
# brick position: (2, 7)
# distance=345.4156915949245
# click_time=0.6517277199904236
#
# brick position: (2, 7)
# distance=237.53947040439405
# click_time=0.4481876800082907
#
# brick position: (2, 7)
# distance=219.5449840010015
# click_time=0.41423581886981414
#
# brick position: (2, 7)
# distance=251.66843266488547
# click_time=0.47484609936770844
#
# brick position: (2, 7)
# distance=228.84492565927695
# click_time=0.4317828786024093
#
# brick position: (2, 7)
# distance=325.1491965236882
# click_time=0.6134890500446947
#
# brick position: (2, 7)
# distance=235.46761985462035
# click_time=0.44427852802758555
#
# brick position: (2, 7)
# distance=183.48024416813925
# click_time=0.34618913993988537
#
# brick position: (2, 7)
# distance=371.80909079795236
# click_time=0.7015265864112309
#
# brick position: (2, 7)
# distance=144.06248644251562
# click_time=0.27181601215568985
#
# brick position: (2, 7)
# distance=292.2618688778952
# click_time=0.5514374884488589
#
# brick position: (2, 7)
# distance=139.29106216839614
# click_time=0.2628133248460304
#
# brick position: (2, 7)
# distance=265.9398428216426
# click_time=0.501773288342722
#
# brick position: (2, 7)
# distance=260.2844597743015
# click_time=0.4911027542911349
#
# brick position: (2, 7)
# distance=308.72965520014435
# click_time=0.5825087833964988
#
# brick position: (2, 7)
# distance=385.12984823303424
# click_time=0.7266600910057249
#
# brick position: (2, 7)
# distance=101.25709851659784
# click_time=0.1910511292765997
#
# brick position: (2, 7)
# distance=317.29481558953967
# click_time=0.59866946337649
#
# brick position: (2, 7)
# distance=358.6153928653928
# click_time=0.6766328167271561
#
# brick position: (2, 7)
# distance=393.37768111574405
# click_time=0.7422220398410265
#
# brick position: (2, 7)
# distance=310.2289477144259
# click_time=0.58533763719703
#
# brick position: (2, 7)
# distance=115.97413504743201
# click_time=0.2188191227310038
#
# brick position: (2, 7)
# distance=377.89548819746443
# click_time=0.7130103550895556
#
# brick position: (2, 7)
# distance=343.45596515419555
# click_time=0.6480301229324444
#
# brick position: (2, 7)
# distance=227.37853900489378
# click_time=0.4290161113299883
#
# brick position: (2, 7)
# distance=236.57979626333267
# click_time=0.44637697408175975
#
# brick position: (2, 7)
# distance=363.2987751149183
# click_time=0.6854693870092798
#
# brick position: (2, 7)
# distance=245.34873140083687
# click_time=0.46292213471856014
#
# brick position: (2, 7)
# distance=402.88956303185614
# click_time=0.7601689868525587
#
# brick position: (2, 7)
# distance=367.03405836516043
# click_time=0.6925170912550197
#
# brick position: (2, 7)
# distance=124.53112060846478
# click_time=0.2349643785065373
#
# brick position: (2, 7)
# distance=166.48123017325406
# click_time=0.3141155286287812
#
# brick position: (2, 7)
# distance=222.26560687609768
# click_time=0.4193690695775428
#
# brick position: (2, 7)
# distance=137.7679207943562
# click_time=0.2599394731968985
#
# brick position: (2, 7)
# distance=134.07833531186162
# click_time=0.2529779911544559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 while True:  # 获取鼠标当前位置
#       3     while(1):
# ----> 4         if keyboard.is_pressed('q'):
#       5             break
#       6     x3, y3 = pyautogui.position()
#
# File d:\anoconda\Lib\site-packages\keyboard\__init__.py:410, in is_pressed(hotkey)
#     402 def is_pressed(hotkey):
#     403     """
#     404     Returns True if the key is pressed.
#     405
#    (...)
#     408         is_pressed('ctrl+space') #-> True
#     409     """
# --> 410     _listener.start_if_necessary()
#     412     if _is_number(hotkey):
#     413         # Shortcut.
#     414         with _pressed_events_lock:
#
# File d:\anoconda\Lib\site-packages\keyboard\_generic.py:46, in GenericListener.start_if_necessary(self)
#      44         self.processing_thread.start()
#      45 finally:
# ---> 46     self.lock.release()
#
# KeyboardInterrupt:
